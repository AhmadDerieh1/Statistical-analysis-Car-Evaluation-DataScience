# %%
import numpy as np 
import pandas as pd

# %%
data = pd.read_csv("yellow_tripdata_2019-02.csv")
data
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1     01/02/2019 00:59      01/02/2019 01:07                1
# 1               1     01/02/2019 00:33      01/02/2019 01:03                1
# 2               1     01/02/2019 00:09      01/02/2019 00:09                1
# 3               1     01/02/2019 00:45      01/02/2019 00:51                1
# 4               1     01/02/2019 00:25      01/02/2019 00:28                1
# ...           ...                  ...                   ...              ...
# 1048570         1     05/02/2019 08:28      05/02/2019 08:48                1
# 1048571         1     05/02/2019 08:50      05/02/2019 09:02                1
# 1048572         1     05/02/2019 08:00      05/02/2019 08:14                1
# 1048573         1     05/02/2019 08:20      05/02/2019 08:28                1
# 1048574         1     05/02/2019 08:34      05/02/2019 08:39                1
#
# ...

# %%
def compute_trip_duration(data):
    """
    Takes a data frame and adds a new column for trip duration, calculated as the difference between the 
    tpep_pickup_datetime and tpep_dropoff_datetime columns. 
    Returns the modified data frame.
    """
    # Convert the pickup_datetime and dropoff_datetime columns to datetime objects
    data['tpep_pickup_datetime'] = pd.to_datetime(data['tpep_pickup_datetime'])
    data['tpep_dropoff_datetime'] = pd.to_datetime(data['tpep_dropoff_datetime'])
    
    # Calculate the trip duration as the difference between the pickup and dropoff datetimes
    data['trip_duration'] = data['tpep_dropoff_datetime'] - data['tpep_pickup_datetime']
    return df

# %%
compute_trip_duration(data)
data
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2019-01-02 00:59:00   2019-01-02 01:07:00                1
# 1               1  2019-01-02 00:33:00   2019-01-02 01:03:00                1
# 2               1  2019-01-02 00:09:00   2019-01-02 00:09:00                1
# 3               1  2019-01-02 00:45:00   2019-01-02 00:51:00                1
# 4               1  2019-01-02 00:25:00   2019-01-02 00:28:00                1
# ...           ...                  ...                   ...              ...
# 1048570         1  2019-05-02 08:28:00   2019-05-02 08:48:00                1
# 1048571         1  2019-05-02 08:50:00   2019-05-02 09:02:00                1
# 1048572         1  2019-05-02 08:00:00   2019-05-02 08:14:00                1
# 1048573         1  2019-05-02 08:20:00   2019-05-02 08:28:00                1
# 1048574         1  2019-05-02 08:34:00   2019-05-02 08:39:00                1
#
# ...

# %%
def add_hour_and_day_of_week(data):
    """
    adds new columns for the hour of the day and the day 
    of the week from the  pickup date time column.
    """
    # Convert the pickup_datetime column to a datetime object
    data['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])
    # Add new columns for the hour of the day and the day of the week
    data['hour_of_day'] = data['tpep_pickup_datetime'].dt.hour
    data['day_of_week'] = data['tpep_pickup_datetime'].dt.weekday
    return data

# %%
add_hour_and_day_of_week(data)
data
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2019-01-02 00:59:00   2019-01-02 01:07:00                1
# 1               1  2019-01-02 00:33:00   2019-01-02 01:03:00                1
# 2               1  2019-01-02 00:09:00   2019-01-02 00:09:00                1
# 3               1  2019-01-02 00:45:00   2019-01-02 00:51:00                1
# 4               1  2019-01-02 00:25:00   2019-01-02 00:28:00                1
# ...           ...                  ...                   ...              ...
# 1048570         1  2019-05-02 08:28:00   2019-05-02 08:48:00                1
# 1048571         1  2019-05-02 08:50:00   2019-05-02 09:02:00                1
# 1048572         1  2019-05-02 08:00:00   2019-05-02 08:14:00                1
# 1048573         1  2019-05-02 08:20:00   2019-05-02 08:28:00                1
# 1048574         1  2019-05-02 08:34:00   2019-05-02 08:39:00                1
#
# ...
